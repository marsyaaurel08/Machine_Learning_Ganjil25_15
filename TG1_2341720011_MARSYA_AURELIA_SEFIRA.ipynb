# %% [markdown]
# <a href="https://colab.research.google.com/github/marsyaaurel08/Machine_Learning_Ganjil25_15/blob/main/TG1_2341720011_MARSYA_AURELIA_SEFIRA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRAKTIKUM 1

# %%
# Praktikum 1
# !pip install mne
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 43.4 MB/s eta 0:00:00
# ...

# %%
# Tugas Praktikum 1 Bagian 1
# !pip install scipy wandb pyECG
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %% [markdown]
# **Kegunaan dari masing-masing library tersebut adalah**
#
# *   PyPREP : Library untuk preprocessing data EEG (Electroencephalogram) secara otomatis, berguna untuk membersihkan sinyal EEG dari noise, menghilangkan kanal yang rusak, digunakan sebelum analisis machine learning pada data EEG
# *   Scipy : Berfungsi sebagai library scientific computing yang powerful, berguna untuk operasi aritmatika, statistik, signal processing, interpolasi data dan perhitungan numerik
# *   wandb : Berfungsi sebagai alat experiment tracking untuk machine learning, berguna untuk melihat grafik, akurasi secara real time, membandingkan hasil eksperimen
# *   pyECG : Library untuk analisis sinyal ECG (Electrocardiogram), bergua untuk membaca, preprocessing, visualisasi data ECG

# %% [markdown]
# **Bagian 2**
#
#
# 1.   Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
#
# Jawaban : Pada Agustus, 2024 Korea Selatan digemparkan dengan penggunaan AI untuk membuat dan menyebarkan konten pornografi palsu tanpa sepengetahuan pihak yang terkait. Kasus menonjol di Korea Selatan ini menyebarkan gambar-gambar pornografi palsu dari guru wanita dan siswa dibagikan dalam grup telegram dan bahkan dijual, hal ini jelas melanggar hukum dan etika.
#
# Referensi : https://en.wikipedia.org/wiki/Deepfake_pornography?utm_source=chatgpt.com
#
# 2.   Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.
#
# Jawaban : Dampaknya adalah
#
#
# *   Penggunaan energi listrik yang tinggi, karena pusat data yang digunakan AI memerlukan daya listrik besar sehingga meningkatkan jejak karbon.
# *   Penggunaan air yang banyak, karena server AI memerlukan pendinginan yang menghabiskan banyak air, sehingga berpotensi menambah beban pada sumber daya air.
# *   Emisi karbon banyak digunakan terutama jika masih berbasis bahan bakar fosil, hal ini menghasilkan CO2 yang memperburuk perubahan iklim.
#
# Cara mengatasinya
#
# *   Melakukan daur ulang seperti mengelola limbah elektronik agar tidak merusak lingkungan
# *   Menggunakan energi yang ramah lingkungan (matahari, angin, hidro)
# *   Menggunakan teknik seperti kompresi model dan efisiensi algoritma agar kebutuhan komputasi lebih kecil
# *   Menempatkan data di wilayah dengan iklim dingin untuk mengurangi energi pendinginan
#
# Referensi : https://en.wikipedia.org/wiki/Environmental_impact_of_artificial_intelligence?utm_source=chatgpt.com
#
# https://theconversation.com/ai-generatif-membahayakan-lingkungan-bagaimana-cara-mengatasinya-214871?utm_source=chatgpt.com
#
# https://www.ibm.com/id-id/think/insights/future-ai-energy-efficiency?utm_source=chatgpt.com
#
#
# https://edge.id/id/artikel-id/tantangan-energi-data-center?utm_source=chatgpt.com
